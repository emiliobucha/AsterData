# %%
import math;

# %%
import pandas as pd

# %%
data = pd.read_csv('C:\Users\Emilio\Desktop\AsterData\AsteroidesCometasLimpio.csv')
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Unnamed: 0        id    spkid       full_name    pdes     name neo pha  \
# 0           1  a0000001  2000001         1 Ceres       3    Ceres   N   N
# 1           2  a0000002  2000002        2 Pallas  113863   Pallas   N   N
# 2           3  a0000003  2000003          3 Juno  464251     Juno   N   N
# 3           4  a0000004  2000004         4 Vesta  575437    Vesta   N   N
# 4           5  a0000005  2000005       5 Astraea  681224  Astraea   N   N
#
#       H  diameter   ...          sigma_n      sigma_tp     sigma_per  class  \
# 0  3.34   939.400   ...     3.021800e-12  1.293900e-08  2.373500e-08    MBA
# 1  4.13   545.000   ...     4.998800e-10  4.320600e-05  3.950500e-06    MBA
# 2  5.33   246.596   ...     4.775900e-10  3.803100e-05  3.363300e-06    MBA
# 3  3.20   525.400   ...     2.647300e-10  4.192500e-06  1.292500e-06    MBA
# 4  6.85   106.699   ...     6.631600e-10  3.680600e-05  4.187700e-06    MBA
#
# ...

# %%
data.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid          full_name    pdes        name  \
# 0                1  a0000001  2000001            1 Ceres       3       Ceres
# 1                2  a0000002  2000002           2 Pallas  113863      Pallas
# 2                3  a0000003  2000003             3 Juno  464251        Juno
# 3                4  a0000004  2000004            4 Vesta  575437       Vesta
# 4                5  a0000005  2000005          5 Astraea  681224     Astraea
# 5                6  a0000006  2000006             6 Hebe  692354        Hebe
# 6                7  a0000007  2000007             7 Iris  703480        Iris
# 7                8  a0000008  2000008            8 Flora  714670       Flora
# 8                9  a0000009  2000009            9 Metis  725794       Metis
# 9               10  a0000010  2000010          10 Hygiea       4      Hygiea
# 10              11  a0000011  2000011      11 Parthenope   11132  Parthenope
# ...

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'spkid',
#  'full_name',
#  'pdes',
#  'name',
#  'neo',
#  'pha',
#  'H',
#  'diameter',
#  'albedo',
#  'orbit_id',
#  'epoch',
#  'epoch_mjd',
#  'epoch_cal',
#  'e',
#  'a',
#  'q',
#  'i',
#  'om',
#  'w',
#  'ma',
#  'ad',
#  'n',
#  'tp',
#  'tp_cal',
#  'per',
#  'per_y',
#  'moid',
#  'moid_ld',
#  'moid_jup',
#  't_jup',
#  'sigma_e',
#  'sigma_a',
#  'sigma_q',
#  'sigma_i',
#  'sigma_om',
#  'sigma_w',
#  'sigma_ma',
#  'sigma_ad',
#  'sigma_n',
#  'sigma_tp',
#  'sigma_per',
#  'class',
#  'data_arc',
#  'first_obs',
#  'last_obs',
#  'n_obs_used',
#  'condition_code',
#  'rms']

# %%
data_Porous = data.sample(frac=0.75)

# %%
data_Porous['material']='porous'

# %%
data_Porous.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid                        full_name  \
# 178108      178109  a0178112  2178112              178112 (2006 SZ366)
# 181257      181258  a0181261  2181261               181261 (2005 VY76)
# 232869      232870  a0232873  2232873               232873 (2004 VY23)
# 320766      320767  a0320770  2320770               320770 (2008 EY96)
# 369034      369035  a0369038  2369038                369038 (2008 BE7)
# 328614      328615  a0328618  2328618              328618 (2009 SG144)
# 581217      581218  bK10NB2R  3544244                     (2010 NR112)
# 518932      518933  bK05UN5Z  3317409                     (2005 UZ235)
# 346039      346040  a0346043  2346043              346043 (2007 TO440)
# 234021      234022  a0234025  2234025               234025 (1998 SA34)
# 368429      368430  a0368433  2368433               368433 (2002 VE20)
# 7157          7158  a0007158  2007158             7158 IRTF (1981 ES8)
# ...

# %%
data_Porous.material
# Out:
# 178108    porous
# 181257    porous
# 232869    porous
# 320766    porous
# 369034    porous
# 328614    porous
# 581217    porous
# 518932    porous
# 346039    porous
# 234021    porous
# 368429    porous
# 7157      porous
# 3587      porous
# 16620     porous
# 460470    porous
# 372618    porous
# 7633      porous
# 680759    porous
# 36404     porous
# 376298    porous
# 322876    porous
# 186437    porous
# 266772    porous
# 97774     porous
# 193855    porous
# 604912    porous
# 479208    porous
# 553352    porous
# 260025    porous
# 44881     porous
#            ...
# 486164    porous
# 587855    porous
# 374092    porous
# 568632    porous
# 509664    porous
# 406068    porous
# 218481    porous
# 489086    porous
# 505337    porous
# 379681    porous
# 503850    porous
# 323200    porous
# 178573    porous
# 240695    porous
# 446183    porous
# 315171    porous
# 41584     porous
# 670144    porous
# 41474     porous
# 565427    porous
# 662332    porous
# ...

# %%
data_Rest =data.loc[~data.index.isin(data_Porous.index)]

# %%
data_Rest.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid           full_name    pdes  \
# 2                3  a0000003  2000003              3 Juno  464251
# 8                9  a0000009  2000009             9 Metis  725794
# 10              11  a0000011  2000011       11 Parthenope   11132
# 14              15  a0000015  2000015          15 Eunomia   55658
# 17              18  a0000018  2000018        18 Melpomene   89113
# 22              23  a0000023  2000023           23 Thalia  386395
# 24              25  a0000025  2000025          25 Phocaea  408640
# 29              30  a0000030  2000030           30 Urania  464252
# 30              31  a0000031  2000031       31 Euphrosyne  475375
# 31              32  a0000032  2000032           32 Pomona  486497
# 36              37  a0000037  2000037            37 Fides  542099
# 38              39  a0000039  2000039         39 Laetitia  564323
# 39              40  a0000040  2000040         40 Harmonia  575438
# ...

# %%
data_Dense = data_Rest.sample(frac=0.48)

# %%
data_Metalic = data_Rest.loc[~data_Rest.index.isin(data_Dense.index)]

# %%
data_Dense['material']='dense'

# %%
data_Metalic['material']='metalic'
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Metalic.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid           full_name    pdes  \
# 10              11  a0000011  2000011       11 Parthenope   11132
# 14              15  a0000015  2000015          15 Eunomia   55658
# 17              18  a0000018  2000018        18 Melpomene   89113
# 24              25  a0000025  2000025          25 Phocaea  408640
# 29              30  a0000030  2000030           30 Urania  464252
# 31              32  a0000032  2000032           32 Pomona  486497
# 39              40  a0000040  2000040         40 Harmonia  575438
# 44              45  a0000045  2000045          45 Eugenia  631003
# 48              49  a0000049  2000049            49 Pales  675457
# 50              51  a0000051  2000051          51 Nemausa  682337
# 54              55  a0000055  2000055          55 Pandora  686789
# 67              68  a0000068  2000068             68 Leto  701254
# 80              81  a0000081  2000081      81 Terpsichore  715783
# ...

# %%
data_Dense.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid            full_name    pdes name neo  \
# 501307      501308  bK02N66S  3387104          (2002 NS66)  119649  NaN   N
# 634900      634901  bK13T10U  3649741          (2013 TU10)  261485  NaN   N
# 316784      316785  a0316788  2316788  316788 (1999 TP173)  482924  NaN   N
# 576333      576334  bK10J76X  3569606          (2010 JX76)  199989  NaN   N
# 505585      505586  bK02W24N  3406734          (2002 WN24)  123924  NaN   N
# 127944      127945  a0127945  2127945    127945 (2003 HW6)   31099  NaN   N
# 445676      445677  a0445680  2445680  445680 (2011 UF122)  626204  NaN   N
# 368813      368814  a0368817  2368817  368817 (2006 AP104)  540785  NaN   N
# 429357      429358  a0429361  2429361  429361 (2010 GF121)  608069  NaN   N
# 623539      623540  bK13CE4E  3651611         (2013 CE144)  247980  NaN   N
# 641532      641533  bK14D74O  3664002          (2014 DO74)  267331  NaN   N
# ...

# %%
data_Porous.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid                        full_name  \
# 178108      178109  a0178112  2178112              178112 (2006 SZ366)
# 181257      181258  a0181261  2181261               181261 (2005 VY76)
# 232869      232870  a0232873  2232873               232873 (2004 VY23)
# 320766      320767  a0320770  2320770               320770 (2008 EY96)
# 369034      369035  a0369038  2369038                369038 (2008 BE7)
# 328614      328615  a0328618  2328618              328618 (2009 SG144)
# 581217      581218  bK10NB2R  3544244                     (2010 NR112)
# 518932      518933  bK05UN5Z  3317409                     (2005 UZ235)
# 346039      346040  a0346043  2346043              346043 (2007 TO440)
# 234021      234022  a0234025  2234025               234025 (1998 SA34)
# 368429      368430  a0368433  2368433               368433 (2002 VE20)
# 7157          7158  a0007158  2007158             7158 IRTF (1981 ES8)
# ...

# %%
data_Porous['density']=1500

# %%
data_Dense['density']=3000

# %%
data_Metalic['density']=8000
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total = data_Porous.append([data_Dense,data_Metalic])

# %%
data_Total.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid                        full_name  \
# 178108      178109  a0178112  2178112              178112 (2006 SZ366)
# 181257      181258  a0181261  2181261               181261 (2005 VY76)
# 232869      232870  a0232873  2232873               232873 (2004 VY23)
# 320766      320767  a0320770  2320770               320770 (2008 EY96)
# 369034      369035  a0369038  2369038                369038 (2008 BE7)
# 328614      328615  a0328618  2328618              328618 (2009 SG144)
# 581217      581218  bK10NB2R  3544244                     (2010 NR112)
# 518932      518933  bK05UN5Z  3317409                     (2005 UZ235)
# 346039      346040  a0346043  2346043              346043 (2007 TO440)
# 234021      234022  a0234025  2234025               234025 (1998 SA34)
# 368429      368430  a0368433  2368433               368433 (2002 VE20)
# 7157          7158  a0007158  2007158             7158 IRTF (1981 ES8)
# ...

# %%
import numpy

# %%
data_Total = data_Total[(numpy.isfinite(data_Total.diameter))]

# %%
data_Total.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid                          full_name  \
# 581217      581218  bK10NB2R  3544244                       (2010 NR112)
# 234021      234022  a0234025  2234025                 234025 (1998 SA34)
# 7157          7158  a0007158  2007158               7158 IRTF (1981 ES8)
# 16620        16621  a0016621  2016621                  16621 (1993 FA84)
# 7633          7634  a0007634  2007634      7634 Shizutani-Kou (1982 VO3)
# 36404        36405  a0036405  2036405                  36405 (2000 OB48)
# 97774        97775  a0097775  2097775                   97775 (2000 KN2)
# 260025      260026  a0260029  2260029                 260029 (2004 GQ25)
# 218248      218249  a0218252  2218252                  218252 (2003 AW5)
# 244195      244196  a0244199  2244199                 244199 (2001 YE89)
# 192099      192100  a0192103  2192103                 192103 (2006 CL11)
# ...

# %%
velocidad = 25000;
densidad_sedimentaria = 2500

# %%
data_Total['Dtc']=1.161*numpy.power((data_Total['density']/densidad_sedimentaria),(1./3))*numpy.power((data_Total['diameter']*1000),0.78)*numpy.power(velocidad,0.44)*numpy.power(9.807,-0.22)*numpy.power(numpy.sin(numpy.pi/4),1./3)
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total['Dtc']
# Out:
# 581217    25103.729124
# 234021    23457.004974
# 7157      60497.981843
# 16620     29521.649048
# 7633      59282.288930
# 36404     20989.236613
# 97774     48254.781166
# 260025    21171.270298
# 218248    23377.788111
# 244195    19887.440061
# 192099    37110.590202
# 242690    34017.781694
# 97079     28419.822231
# 53807     22765.863488
# 103528    25598.307528
# 226217    14483.687899
# 4460      91627.979184
# 3135      99006.673836
# 241234    28263.917634
# 67957     12700.293918
# 215403    75140.090050
# 575837    20787.853575
# 63020     36273.076220
# 15564     27632.033041
# 11412     28125.131889
# 34413     42998.617197
# 102468    14070.314424
# 95215     31909.490542
# 24427     40127.018069
# 121309    30933.574961
#               ...
# 703238    25146.702686
# 703420    52702.603854
# 703802    66496.515574
# 703907    39367.234485
# 704243    28398.909112
# 705506    43117.251515
# 705541    45511.482882
# 705799    35024.959992
# 705999    40279.115249
# ...

# %%
data_Total['Dfr']=1.25 * data_Total['Dtc']
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total.loc[data_Total['Dtc']>2560,'Dfr']=1.17*(numpy.power(data_Total[data_Total['Dtc']>2560]['Dtc'] /1000,1.13)/numpy.power(3.2,0.13))
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_Total['Dfr']
# Out:
# 581217     38.390218
# 234021     35.556938
# 7157      103.725030
# 16620      46.107891
# 7633      101.372831
# 36404      31.359749
# 97774      80.337250
# 260025     31.667252
# 218248     35.421278
# 244195     29.506011
# 192099     59.710258
# 242690     54.118298
# 97079      44.168078
# 53807      34.375374
# 103528     39.245971
# 226217     20.621004
# 4460      165.809010
# 3135      180.974429
# 241234     43.894381
# 67957      17.775668
# 215403    132.510837
# 575837     31.019962
# 63020      58.189781
# 15564      42.787102
# 11412      43.650902
# 34413      70.521240
# 102468     19.957202
# 95215      50.343780
# 24427      65.222891
# 121309     48.607400
#              ...
# 703238     38.464487
# 703420     88.753729
# 703802    115.419479
# 703907     63.829113
# 704243     44.131353
# 705506     70.741143
# 705541     75.195713
# 705799     55.932355
# 705999     65.502319
# 706172     49.558866
# 706446     74.848400
# 708605     70.838376
# ...

# %%
data_Total.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0        id    spkid                          full_name  \
# 581217      581218  bK10NB2R  3544244                       (2010 NR112)
# 234021      234022  a0234025  2234025                 234025 (1998 SA34)
# 7157          7158  a0007158  2007158               7158 IRTF (1981 ES8)
# 16620        16621  a0016621  2016621                  16621 (1993 FA84)
# 7633          7634  a0007634  2007634      7634 Shizutani-Kou (1982 VO3)
# 36404        36405  a0036405  2036405                  36405 (2000 OB48)
# 97774        97775  a0097775  2097775                   97775 (2000 KN2)
# 260025      260026  a0260029  2260029                 260029 (2004 GQ25)
# 218248      218249  a0218252  2218252                  218252 (2003 AW5)
# 244195      244196  a0244199  2244199                 244199 (2001 YE89)
# 192099      192100  a0192103  2192103                 192103 (2006 CL11)
# ...

# %%
#data_Total=data_Total.drop(data_Total.index[len(data_Total)-1])

# %%
data_Total['Vbr']=0.032*numpy.power(data_Total['Dfr'],3)
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total['dtc1']=data_Total['Dtc']/(numpy.sqrt(2)*2)
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total['hfr']=0.07*(numpy.power(data_Total['Dtc'],4)/numpy.power(data_Total['Dfr'],3))
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total['tbr']=2.8*data_Total['Vbr']*((data_Total['dtc1']+data_Total['hfr'])/(data_Total['dtc1']*numpy.power(data_Total['Dfr'],2)))
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total['dfr1']=(data_Total['dtc1']+data_Total['hfr']-data_Total['tbr'])/1000
# Out:
# C:\Users\Emilio\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_Total.loc[data_Total['Dtc']>2560,'dfr1']=0.4*(numpy.power(data_Total[data_Total['Dtc']>2560]['Dfr'],0.3))

# %%
data_Total.loc[data_Total['Dtc']<2560,'Dfr']=data_Total['Dfr']/1000

# %%
data_Total.head()
# Out:
#         Unnamed: 0        id    spkid                        full_name  \
# 581217      581218  bK10NB2R  3544244                     (2010 NR112)
# 234021      234022  a0234025  2234025               234025 (1998 SA34)
# 7157          7158  a0007158  2007158             7158 IRTF (1981 ES8)
# 16620        16621  a0016621  2016621                16621 (1993 FA84)
# 7633          7634  a0007634  2007634    7634 Shizutani-Kou (1982 VO3)
#
#           pdes           name neo pha     H  diameter    ...         rms  \
# 581217  205177            NaN   N   N  15.4     3.277    ...     0.35179
# 234021  390874            NaN   N   N  15.2     3.004    ...     0.59678
# 7157    705238           IRTF   N   N  12.7    10.121    ...     0.52543
# 16620    73710            NaN   N   N  14.0     4.034    ...     0.56240
# 7633    710599  Shizutani-Kou   N   N  13.7     9.861    ...     0.58034
#
#        material  density           Dtc         Dfr           Vbr  \
# ...

# %%
data_Total.loc[data_Total['Dtc']<2560]
# Out:
#         Unnamed: 0        id    spkid            full_name    pdes name neo  \
# 569256      569257  bK10A40G  3485632          (2010 AG40)  189826  NaN   Y
# 573234      573235  bK10F00T  3512284            (2010 FT)  195874  NaN   Y
# 574839      574840  bK10H00A  3516633            (2010 HA)  197456  NaN   Y
# 575712      575713  bK10HA4Z  3521512         (2010 HZ104)  198588  NaN   Y
# 569210      569211  bK10A30J  3485263          (2010 AJ30)  189897  NaN   Y
# 579320      579321  bK10M01Y  3532406           (2010 MY1)  204279  NaN   Y
# 587262      587263  bK10VD9K  3551475         (2010 VK139)  211829  NaN   Y
# 569838      569839  bK10B02K  3486442           (2010 BK2)  191009  NaN   Y
# 571181      571182  bK10C44O  3508128          (2010 CO44)  192744  NaN   Y
# 495531      495532  bJ98W02B  3015695           (1998 WB2)  112861  NaN   Y
# 572233      572234  bK10D00L  3508142            (2010 DL)  193841  NaN   Y
# ...

# %%
data_Total.to_csv('C:\Users\Emilio\Desktop\AsterData\Asteroides-Crater.csv')

# %%
data_Total.Dtc
# Out:
# 581217    25103.729124
# 234021    23457.004974
# 7157      60497.981843
# 16620     29521.649048
# 7633      59282.288930
# 36404     20989.236613
# 97774     48254.781166
# 260025    21171.270298
# 218248    23377.788111
# 244195    19887.440061
# 192099    37110.590202
# 242690    34017.781694
# 97079     28419.822231
# 53807     22765.863488
# 103528    25598.307528
# 226217    14483.687899
# 4460      91627.979184
# 3135      99006.673836
# 241234    28263.917634
# 67957     12700.293918
# 215403    75140.090050
# 575837    20787.853575
# 63020     36273.076220
# 15564     27632.033041
# 11412     28125.131889
# 34413     42998.617197
# 102468    14070.314424
# 95215     31909.490542
# 24427     40127.018069
# 121309    30933.574961
#               ...
# 703238    25146.702686
# 703420    52702.603854
# 703802    66496.515574
# 703907    39367.234485
# 704243    28398.909112
# 705506    43117.251515
# 705541    45511.482882
# 705799    35024.959992
# 705999    40279.115249
# ...

# %%
velocidad = 40000 #m/s^(-2)
densidad_sedimentaria = 2500 #Kg/m^3 
angulo = numpy.pi/4 #Radianes
ejemplo = data_Total[data_Total.pha == "Y"].sample(1)

ejemplo['Dtc']=1.161*numpy.power((ejemplo['density']/densidad_sedimentaria),(1./3))*numpy.power((ejemplo['diameter']*1000),0.78)*numpy.power(velocidad,0.44)*numpy.power(9.807,-0.22)*numpy.power(numpy.sin(angulo/4),1./3)
ejemplo['Dfr']=1.25 * ejemplo['Dtc']
ejemplo.loc[ejemplo['Dtc']>2560,'Dfr']=1.17*(numpy.power(ejemplo[ejemplo['Dtc']>2560]['Dtc'] /1000,1.13)/numpy.power(3.2,0.13))
ejemplo['Vbr']=0.032*numpy.power(ejemplo['Dfr'],3)
ejemplo['dtc1']=data_Total['Dtc']/(numpy.sqrt(2)*2)
ejemplo['hfr']=0.07*(numpy.power(ejemplo['Dtc'],4)/numpy.power(ejemplo['Dfr'],3))
ejemplo['tbr']=2.8*ejemplo['Vbr']*((ejemplo['dtc1']+ejemplo['hfr'])/(ejemplo['dtc1']*numpy.power(ejemplo['Dfr'],2)))
ejemplo['dfr1']=(ejemplo['dtc1']+ejemplo['hfr']-ejemplo['tbr'])/1000
ejemplo.loc[ejemplo['Dtc']>2560,'dfr1']=0.4*(numpy.power(ejemplo[ejemplo['Dtc']>2560]['Dfr'],0.3))
ejemplo.Dtc = ejemplo.Dtc/1000
ejemplo.dtc1 = ejemplo.dtc1/1000
ejemplo = ejemplo.rename(columns={'Dtc': 'Diametro_Crater_Impacto', 'Dfr': 'Diametro_Final_Crater', 'dtc1': 'Profundidad_Inicial_Crater', 'dfr1': 'Profundidad_Final_Crater'})
cols = list(['id'] + ['full_name'] + ['pha']+['Diametro_Crater_Impacto']+['Diametro_Final_Crater']+['Profundidad_Inicial_Crater']+['Profundidad_Final_Crater'])
ejemplo[cols]
# Out:
#               id            full_name pha  Diametro_Crater_Impacto  \
# 582106  bK10OA1N         (2010 ON101)   Y                 2.598921
#
#         Diametro_Final_Crater  Profundidad_Inicial_Crater  \
# 582106               2.959596                    1.147761
#
#         Profundidad_Final_Crater
# 582106                  0.553898
